# %% [markdown]
# # Desafio 1 - Grupo 7 - Sebastian Leonardi

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', 50)

# %% [markdown]
# ### Carga de csv con datos

# %%
prop = pd.read_csv("properatti.csv"
           , encoding = 'utf-8',)

# %%
prop.head()
# Out:
#    Unnamed: 0 operation property_type place_name  \
# 0           0      sell            PH  Mataderos
# 1           1      sell     apartment   La Plata
# 2           2      sell     apartment  Mataderos
# 3           3      sell            PH    Liniers
# 4           4      sell     apartment     Centro
#
#                              place_with_parent_names country_name  \
# 0              |Argentina|Capital Federal|Mataderos|    Argentina
# 1        |Argentina|Bs.As. G.B.A. Zona Sur|La Plata|    Argentina
# 2              |Argentina|Capital Federal|Mataderos|    Argentina
# 3                |Argentina|Capital Federal|Liniers|    Argentina
# 4  |Argentina|Buenos Aires Costa Atlántica|Mar de...    Argentina
#
#                      state_name  geonames_id                  lat-lon  \
# 0               Capital Federal    3430787.0  -34.6618237,-58.5088387
# 1        Bs.As. G.B.A. Zona Sur    3432039.0  -34.9038831,-57.9643295
# ...

# %% [markdown]
# ## Algunos datos basicos del dataframe

# %%
prop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121220 entries, 0 to 121219
# Data columns (total 26 columns):
# Unnamed: 0                    121220 non-null int64
# operation                     121220 non-null object
# property_type                 121220 non-null object
# place_name                    121197 non-null object
# place_with_parent_names       121220 non-null object
# country_name                  121220 non-null object
# state_name                    121220 non-null object
# geonames_id                   102503 non-null float64
# lat-lon                       69670 non-null object
# lat                           69670 non-null float64
# lon                           69670 non-null float64
# price                         100810 non-null float64
# currency                      100809 non-null object
# price_aprox_local_currency    100810 non-null float64
# price_aprox_usd               100810 non-null float64
# surface_total_in_m2           81892 non-null float64
# ...

# %%
prop.property_type.value_counts()
# Out:
# apartment    71065
# house        40268
# PH            5751
# store         4136
# Name: property_type, dtype: int64

# %%
prop.operation.value_counts()
# Out:
# sell    121220
# Name: operation, dtype: int64

# %% [markdown]
# ### Se borran la columnas operation, country_name y otras porque son irrelevantes o tienen valores unicos. No aportan informacion

# %%
prop.drop('operation', axis=1, inplace=True)

# %%
prop.drop('image_thumbnail', axis=1, inplace=True)

# %%
prop.drop('properati_url', axis=1, inplace=True)

# %%
prop.country_name.value_counts()
# Out:
# Argentina    121220
# Name: country_name, dtype: int64

# %%
prop.drop("country_name", axis=1, inplace=True)

# %%
#prop[13:]
prop.loc[prop.price_aprox_local_currency].isnull().head(10)

#print(train[train["Electrical"].isnull()][null_columns])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-a203b247b54e> in <module>
#       1 #prop[13:]
# ----> 2 prop.loc[prop.price_aprox_local_currency].isnull().head(10)
#       3
#       4 #print(train[train["Electrical"].isnull()][null_columns])
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1498
#    1499             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1500             return self._getitem_axis(maybe_callable, axis=axis)
#    1501
#    1502     def _is_scalar_access(self, key):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1900                     raise ValueError('Cannot index with multidimensional key')
#    1901
# -> 1902                 return self._getitem_iterable(key, axis=axis)
#    1903
# ...

# %%
prop[['place_name','geonames_id']].loc[prop.place_name=='La Plata'].groupby(['place_name']).count()
# Out:
#             geonames_id
# place_name
# La Plata           2534

# %%
prop.loc[prop.place_name=='Abasto']

# %%
prop.place_name.value_counts()
# Out:
# Córdoba                           9254
# Rosario                           8504
# Mar del Plata                     6534
# Tigre                             3324
# Nordelta                          3315
# Belgrano                          2992
# Palermo                           2885
# La Plata                          2534
# Caballito                         2273
# Pilar                             2228
# Villa Urquiza                     1632
# Olivos                            1590
# Recoleta                          1547
# Lomas de Zamora                   1529
# Flores                            1354
# Ituzaingó                         1340
# Villa Crespo                      1331
# Capital Federal                   1297
# San Telmo                         1216
# Morón                             1209
# Almagro                           1165
# Barrio Norte                      1140
# Ramos Mejía                       1127
# Martínez                          1058
# ...

# %%
prop.place_with_parent_names.value_counts()
# Out:
# |Argentina|Santa Fe|Rosario|                                                         8504
# |Argentina|Córdoba|Córdoba|                                                          6606
# |Argentina|Buenos Aires Costa Atlántica|Mar del Plata|                               6534
# |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|Nordelta|                                  3315
# |Argentina|Capital Federal|Belgrano|                                                 2992
# |Argentina|Capital Federal|Palermo|                                                  2885
# |Argentina|Córdoba|                                                                  2648
# |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|                                           2359
# |Argentina|Capital Federal|Caballito|                                                2273
# |Argentina|Bs.As. G.B.A. Zona Norte|Pilar|                                           1857
# ...

# %%
prop.state_name.value_counts()
# Out:
# Capital Federal                 32316
# Bs.As. G.B.A. Zona Norte        25560
# Bs.As. G.B.A. Zona Sur          13952
# Córdoba                         12069
# Santa Fe                        10172
# Buenos Aires Costa Atlántica    10006
# Bs.As. G.B.A. Zona Oeste         9322
# Buenos Aires Interior            2291
# Río Negro                         808
# Neuquén                           733
# Mendoza                           681
# Tucumán                           674
# Corrientes                        583
# Misiones                          464
# Entre Ríos                        369
# Salta                             278
# Chubut                            259
# San Luis                          252
# La Pampa                          157
# Formosa                            65
# Chaco                              57
# San Juan                           40
# Tierra Del Fuego                   31
# Catamarca                          27
# Jujuy                              26
# ...

# %%
prop.loc[:5,'geonames_id':'price']
# Out:
#    geonames_id                  lat-lon        lat        lon     price
# 0    3430787.0  -34.6618237,-58.5088387 -34.661824 -58.508839   62000.0
# 1    3432039.0  -34.9038831,-57.9643295 -34.903883 -57.964330  150000.0
# 2    3430787.0  -34.6522615,-58.5229825 -34.652262 -58.522982   72000.0
# 3    3431333.0  -34.6477969,-58.5164244 -34.647797 -58.516424   95000.0
# 4    3435548.0  -38.0026256,-57.5494468 -38.002626 -57.549447   64000.0
# 5    3433657.0   -33.0140714,-58.519828 -33.014071 -58.519828       NaN

# %%
prop.loc[:5,'price':'surface_covered_in_m2']
# Out:
#       price currency  price_aprox_local_currency  price_aprox_usd  \
# 0   62000.0      USD                   1093959.0          62000.0
# 1  150000.0      USD                   2646675.0         150000.0
# 2   72000.0      USD                   1270404.0          72000.0
# 3   95000.0      USD                   1676227.5          95000.0
# 4   64000.0      USD                   1129248.0          64000.0
# 5       NaN      NaN                         NaN              NaN
#
#    surface_total_in_m2  surface_covered_in_m2
# 0                 55.0                   40.0
# 1                  NaN                    NaN
# 2                 55.0                   55.0
# 3                  NaN                    NaN
# 4                 35.0                   35.0
# 5                 53.0                    NaN

# %%
prop.loc[:5,'surface_covered_in_m2':'expenses']
# Out:
#    surface_covered_in_m2  price_usd_per_m2  price_per_m2  floor  rooms  \
# 0                   40.0       1127.272727   1550.000000    NaN    NaN
# 1                    NaN               NaN           NaN    NaN    NaN
# 2                   55.0       1309.090909   1309.090909    NaN    NaN
# 3                    NaN               NaN           NaN    NaN    NaN
# 4                   35.0       1828.571429   1828.571429    NaN    NaN
# 5                    NaN               NaN           NaN    NaN    NaN
#
#    expenses
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# 5       NaN

# %%
prop.loc[:5,'expenses':'title']
# Out:
#    expenses                                        description  \
# 0       NaN  2 AMBIENTES TIPO CASA PLANTA BAJA POR PASILLO,...
# 1       NaN  Venta de departamento en décimo piso al frente...
# 2       NaN  2 AMBIENTES 3ER PISO LATERAL LIVING COMEDOR AM...
# 3       NaN  PH 3 ambientes con patio. Hay 3 deptos en lote...
# 4       NaN  DEPARTAMENTO CON FANTÁSTICA ILUMINACIÓN NATURA...
# 5       NaN  Casa en el perímetro del barrio 338, ubicada e...
#
#                                                title
# 0                 2 AMB TIPO CASA SIN EXPENSAS EN PB
# 1  VENTA Depto 2 dorm. a estrenar 7 e/ 36 y 37   ...
# 2           2 AMB 3ER PISO CON ASCENSOR APTO CREDITO
# 3                       PH 3 amb. cfte. reciclado
# 4  DEPTO 2 AMB AL CONTRAFRENTE ZONA CENTRO/PLAZA ...
# 5  Casa Barrio 338. Sobre calle 3 de caballería, ...

# %%
prop[['lat-lon','title']].groupby('lat-lon').count().sort_values('title', ascending=False)
# Out:
#                                title
# lat-lon
# -34.4026444,-58.6684776          312
# -34.40014,-58.64985              271
# -34.6428675967,-58.4376599743    259
# -34.425087,-58.5796585           224
# -34.5895459,-58.3973636          156
# -34.5711496,-58.4232966          142
# -31.4200833,-64.188776           132
# -34.5620844,-58.4566864          116
# -34.42508698,-58.57965851        115
# -38.416097,-63.616672            109
# -34.4778621,-58.9091671          106
# -34.6298857,-58.4638709           95
# -34.6177194,-58.3620561           87
# -34.4235326,-58.5903044           84
# -34.597985113,-58.426512964       84
# -34.6209278,-58.4458736           83
# -31.420572,-64.49949              76
# -34.6211839,-58.3731163           75
# -38.0051554,-57.5444733           74
# -34.505208,-58.493394             74
# -34.629352033,-58.5048034193      71
# -34.36000061,-58.59700012         65
# -34.577168,-58.538654             65
# -34.4465229,-58.6338743           64
# ...

# %%
prop[prop['lat-lon'] == '-34.4026444,-58.6684776']
# Out:
#         Unnamed: 0 property_type         place_name  \
# 1284          1284     apartment  Barrio Los Alisos
# 1287          1287     apartment  Barrio Los Alisos
# 1306          1306     apartment  Barrio Los Alisos
# 4648          4648     apartment           Nordelta
# 9502          9502         house  Barrio Los Alisos
# 13765        13765     apartment           Nordelta
# 18574        18574     apartment   BarrioPortezuelo
# 18943        18943     apartment  Barrio Los Alisos
# 18946        18946     apartment  Barrio Los Alisos
# 18952        18952     apartment  Barrio Los Alisos
# 18953        18953     apartment  Barrio Los Alisos
# 18955        18955     apartment  Barrio Los Alisos
# 18960        18960     apartment  Barrio Los Alisos
# 18964        18964     apartment  Barrio Los Alisos
# 18972        18972         house           Nordelta
# 18979        18979     apartment  Barrio Los Alisos
# 18981        18981     apartment  Barrio Los Alisos
# ...
